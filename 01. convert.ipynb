# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import csv

# %%
x = open ('/content/drive/My Drive/Colab Notebooks/Datasets/corrected', 'r')

# %%
i=0
lines = list()
for l in x:
    words = l.split(",")
    lines.append(words)
    i = i+1
    
with open ('/content/drive/My Drive/Colab Notebooks/Datasets/PCAP.csv', 'w') as writeFile:
    writer = csv.writer (writeFile)
    writer.writerows(lines)

# %%
y = open ('/content/drive/My Drive/Colab Notebooks/Datasets/kddcup.testdata.unlabeled', 'r')

# %%
i=0
line = list()
for l in y:
    words = l.split(",")
    line.append(words)
    i = i+1
    
with open ('/content/drive/My Drive/Colab Notebooks/Datasets/PCAPTest.csv', 'w') as writeFile:
    writer = csv.writer (writeFile)
    writer.writerows(line)
